# %% [markdown]
# <a href="https://colab.research.google.com/github/itsmeeeeeee/BERT_Probing/blob/main/extract_embedding_6m.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.34.1-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 58.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 41.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 67.3 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 88.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 40.6 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.34.1

# %%
import pandas as pd
import numpy as np
from ast import literal_eval
from transformers import BertTokenizer, BertModel, AutoTokenizer
import torch
from pathlib import Path
from typing import Dict

# %%
model_ckpt = "bert-base-cased"
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
model = BertModel.from_pretrained(model_ckpt)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]

# %%
# Returns a list of lists of indices for each subtoken from the tokenizer, if more than one subtoken appears

def get_indexof_subtokens(tokenizer_output):
    result = []
    temp_liste = [tokenizer_output[0]]  # Start with the first word in the temporary list

    for i in range(1, len(tokenizer_output)):
        # If the current word has the same property as the previous word
        if tokenizer_output[i][:2] == "##" and tokenizer_output[i - 1][:2] == "##":
            temp_liste.append(i)



        else:
            if len(temp_liste) > 1:  # If the temporary list contains more than one word, add it to the result.
                result.append(temp_liste)
            temp_liste = [i]  # Start a new temporary list with the current word.

    # Add the last temporary list to the result if it contains more than one word
    if len(temp_liste) > 1:
        result.append(temp_liste)

    return result

ll = ['[CLS]', 'Celebration', 'Shooting', 'Turn', '##s', 'Wedding', 'Into', 'a', 'Fun', '##eral', 'in', 'Southern',
      'Gaza', 'Strip', 'As', '##ad', '1', '/', '20', '/', '2007', 'Gaza', '-', 'UP', '##I', 'The', 'cheer', '##s',
      'and', 'hail', '##s', 'of', 'happiness', 'at', 'a', 'wedding', 'in', 'Khan', 'You', '##nes', 'in', 'the',
      'southern', 'Gaza', 'Strip', 'turned', 'into', 'screams', 'and', 'moan', '##s', 'of', 'pain', 'after', 'one',
      'of', 'the', 'c', '##ele', '##bra', '##tors', 'lost', 'control', 'of', 'his', 'weapon', ',', 'from', 'which', 'a',
      'number', 'of', 'bullets', 'were', 'released', 'that', 'killed', 'the', 'groom', "'", 's', 'brother', 'and',
      'hit', 'three', 'other', 'relatives', 'of', 'his', ',', 'turning', 'the', 'wedding', 'into', 'a', 'funeral', 'in',
      'moments', 'c', '##ele', '##bra', '##tors', '[SEP]']

get_indexof_subtokens(ll)
# Out:
# [[58, 59, 60], [99, 100, 101]]

# %%
"""Returns three lists: one list with main words (only those tokenized into a single subword),
   one with subword related to the main word, and one list with tokenizer indices of the main words.
    All three lists are of the same length"""

def get_main_token_subtoken_embed_index(tokens):
    main_token = []
    subtoken = []
    embed_index_main_token = []

    for i in range(len(tokens) - 1):
        s = ""
        if "##" in tokens[i] and "##" not in tokens[i - 1] and "##" not in tokens[i + 1]:
            s += tokens[i - 1]
            subtoken.append(tokens[i])
            s += tokens[i]
            embed_index_main_token.append(i - 1)


        main_token.append(s.replace("##", ""))
    main_token = [x for x in main_token if x != ""]
    return main_token, subtoken, embed_index_main_token


ll = ['[CLS]', 'Celebration', 'Shooting', 'Turn', '##s', 'Wedding', 'Into', 'a', 'Fun', '##eral', 'in', 'Southern',
      'Gaza', 'Strip', 'As', '##ad', '1', '/', '20', '/', '2007', 'Gaza', '-', 'UP', '##I', 'The', 'cheer', '##s',
      'and', 'hail', '##s', 'of', 'happiness', 'at', 'a', 'wedding', 'in', 'Khan', 'You', '##nes', 'in', 'the',
      'southern', 'Gaza', 'Strip', 'turned', 'into', 'screams', 'and', 'moan', '##s', 'of', 'pain', 'after', 'one',
      'of', 'the', 'c', '##ele', '##bra', '##tors', 'lost', 'control', 'of', 'his', 'weapon', ',', 'from', 'which', 'a',
      'number', 'of', 'bullets', 'were', 'released', 'that', 'killed', 'the', 'groom', "'", 's', 'brother', 'and',
      'hit', 'three', 'other', 'relatives', 'of', 'his', ',', 'turning', 'the', 'wedding', 'into', 'a', 'funeral', 'in',
      'moments', 'c', '##ele', '##bra', '##tors', '[SEP]']
main_token, subtoken, embed_index = get_main_token_subtoken_embed_index(ll)
print(main_token)
print(subtoken)
print(embed_index)
# Out:
# ['Turns', 'Funeral', 'Asad', 'UPI', 'cheers', 'hails', 'Younes', 'moans']
# ['##s', '##eral', '##ad', '##I', '##s', '##s', '##nes', '##s']
# [3, 8, 14, 23, 26, 29, 38, 49]

# %%
"""Returns three lists: one list with main words (only those tokenized into multi subwords),
   one with list of subwords related to the main words, and one list with tokenizer indices of the main words.
    All three lists are of the same length"""

def get_main_tokens_subtokens_embed_index(tokenizer_output):
    index_subtokens = get_indexof_subtokens(tokenizer_output)
    main_words = []
    subwords = []
    embed_index = []
    s = ""
    for inds in index_subtokens:
        #print(".......",res[0]-1)
        s += tokenizer_output[inds[0] - 1]
        l = []
        for ind in inds:
            l.append(tokenizer_output[ind])

            s += tokenizer_output[ind]
        subwords.append(l)
        main_words.append(s.replace("##", ""))
        s = ""
        embed_index.append(inds[0] - 1)

    return main_words, subwords, embed_index

ll = ['[CLS]', 'Celebration', 'Shooting', 'Turn', '##s', 'Wedding', 'Into', 'a', 'Fun', '##eral', 'in', 'Southern',
      'Gaza', 'Strip', 'As', '##ad', '1', '/', '20', '/', '2007', 'Gaza', '-', 'UP', '##I', 'The', 'cheer', '##s',
      'and', 'hail', '##s', 'of', 'happiness', 'at', 'a', 'wedding', 'in', 'Khan', 'You', '##nes', 'in', 'the',
      'southern', 'Gaza', 'Strip', 'turned', 'into', 'screams', 'and', 'moan', '##s', 'of', 'pain', 'after', 'one',
      'of', 'the', 'c', '##ele', '##bra', '##tors', 'lost', 'control', 'of', 'his', 'weapon', ',', 'from', 'which', 'a',
      'number', 'of', 'bullets', 'were', 'released', 'that', 'killed', 'the', 'groom', "'", 's', 'brother', 'and',
      'hit', 'three', 'other', 'relatives', 'of', 'his', ',', 'turning', 'the', 'wedding', 'into', 'a', 'funeral', 'in',
      'moments', 'c', '##ele', '##bra', '##tors', '[SEP]']
main_words, subwords, embed_index = get_main_tokens_subtokens_embed_index(ll)
print(main_words)
print(subwords)  #teilwort,embed_index)
print(embed_index)
# Out:
# ['celebrators', 'celebrators']
# [['##ele', '##bra', '##tors'], ['##ele', '##bra', '##tors']]
# [57, 98]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#The data is read from Google Drive
file_path = "/content/drive/My Drive/embedding_data/final_endlabels_with_sentences_word_count.csv"

final_df = pd.read_csv(file_path)
# Out:
# <ipython-input-8-44c19300809e>:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   final_df = pd.read_csv(file_path)

# %%
"""
This sentence appears twice consecutively in the dataset and has the same sentence number.
This causes issues with indexing the words within a sentence. Refer to the function "find_index_2".Therefore, it is deleted."""

final_df[final_df["Word"]=="worst"][100:150]
final_df[(final_df.index == 5222032)]["Sentence"].tolist()[0]
f_d=final_df[(final_df["Sentence_no"] != 264185)]

# %%
# Filters out the unnecessary columns for further processing
select_columns = f_d[["Sentence_row","Word_count","Sentence", "Sentence_no", "Word", "POS", "end_labels"]]
select_columns
# Out:
#                                               Sentence_row  Word_count  \
# 0        Celebration Shooting Turns Wedding Into a Fune...        82.0
# 1        Celebration Shooting Turns Wedding Into a Fune...        82.0
# 2        Celebration Shooting Turns Wedding Into a Fune...        82.0
# 3        Celebration Shooting Turns Wedding Into a Fune...        82.0
# 4        Celebration Shooting Turns Wedding Into a Fune...        82.0
# ...                                                    ...         ...
# 5910736  Barak is facing mounting pressure ICH from wit...        44.0
# 5910737  Barak is facing mounting pressure ICH from wit...        44.0
# 5910738  Barak is facing mounting pressure ICH from wit...        44.0
# 5910739  Barak is facing mounting pressure ICH from wit...        44.0
# 5910740  Barak is facing mounting pressure ICH from wit...        44.0
#
#                                                   Sentence  Sentence_no  \
# 0        ('Celebration', 'Shooting', 'Turns', 'Wedding'...            0
# 1        ('Celebration', 'Shooting', 'Turns', 'Wedding'...            0
# 2        ('Celebration', 'Shooting', 'Turns', 'Wedding'...            0
# 3        ('Celebration', 'Shooting', 'Turns', 'Wedding'...            0
# 4        ('Celebration', 'Shooting', 'Turns', 'Wedding'...            0
# ...                                                    ...          ...
# 5910736  ('Barak', 'is', 'facing', 'mounting', 'pressur...       307833
# 5910737  ('Barak', 'is', 'facing', 'mounting', 'pressur...       307833
# 5910738  ('Barak', 'is', 'facing', 'mounting', 'pressur...       307833
# 5910739  ('Barak', 'is', 'facing', 'mounting', 'pressur...       307833
# 5910740  ('Barak', 'is', 'facing', 'mounting', 'pressur...       307833
#
#                 Word    POS  end_labels
# 0        Celebration  PROPN         NaN
# 1           Shooting  PROPN         NaN
# 2              Turns   VERB         NaN
# 3            Wedding   NOUN         NaN
# 4               Into    ADP         NaN
# ...              ...    ...         ...
# 5910736         drop   VERB         NaN
# 5910737          out    ADP         NaN
# 5910738           of    ADP         NaN
# 5910739          the    DET         NaN
# 5910740         race   NOUN         NaN
#
# [5910725 rows x 7 columns]

# %%
select_columns.shape
# Out:
# (5910725, 7)

# %%
""" 1. Sentences longer than 5 words are selected because the same sentences frequently appear in the dataset with same sentence numbers.
This complicates the mapping of the embedding vector to the word in the dataset."""

""" 2. Sentences shorter than 500 words are selected to ensure that the allowed length of the BERT tokenizer is not exceeded."""

filtered_df = select_columns[(select_columns['Word_count'] < 500) & (select_columns['Word_count'] > 5)]

# %%
filtered_df.shape
# Out:
# (5765986, 7)

# %%
# In this step, only last two million data points are used.

final_data_3_2000000=filtered_df[4000000:]

# %%
# Raw sentences are saved without duplicates

texts_3_2000000 = final_data_3_2000000["Sentence_row"].tolist()
texts_ohne_dublikate_3_2000000 = pd.Series(texts_3_2000000).dropna().drop_duplicates().tolist()
print(len(texts_ohne_dublikate_3_2000000))
# Out:
# 17107

# %%
import time
start_time = time.time()


"""Extract the main information for the correct assignment of the embedding vector
  to each word in the respective sentence. It returns a list of main tokens, a list of subtokens,
  a list of indices for the assignment of the embedding vector, a list for all tokens, and a list
  with all contextualized vectors for a sentence."""


all_main_tokens_3_2000000 = []
all_subtokens_3_2000000 = []
all_embeded_index_3_2000000 = []
all_tokens_3_2000000 = []
all_contextualized_vectors_3_2000000= []
for ind, el in enumerate(texts_ohne_dublikate_3_2000000):

    tokenized_input = tokenizer(el)
    tokens = tokenizer.convert_ids_to_tokens(tokenized_input["input_ids"])
    #print(el)
    main_tokens, subtokens, embed_index_main_tokens= get_main_tokens_subtokens_embed_index(tokens)
    main_token, subtoken, embed_index_main_token = get_main_token_subtoken_embed_index(tokens)
    main_tokens += main_token
    subtokens += subtoken
    embed_index_main_tokens += embed_index_main_token
    all_tokens_3_2000000.append(tokens)
    all_main_tokens_3_2000000.append(main_tokens)
    all_subtokens_3_2000000.append(subtokens)
    all_embeded_index_3_2000000.append(embed_index_main_tokens)
    input_vectors = []
    with torch.no_grad():
        outputs = model(torch.tensor(tokenized_input["input_ids"]).unsqueeze(0))
        contextualized_vectors = outputs.last_hidden_state
        for el in contextualized_vectors:
          all_contextualized_vectors_3_2000000.append(el)



    print(f"""##########################################################################
############################# new element {ind} ##############################
########################################################################""")
elapsed_time_seconds = time.time() - start_time
elapsed_time_minutes = elapsed_time_seconds / 60

print(f"Der Code hat {elapsed_time_minutes:.2f} Minuten gedauert.")
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# ########################################################################
# ##########################################################################
# ############################# new element 15441 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15442 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15443 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15444 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15445 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15446 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15447 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15448 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15449 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15450 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15451 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15452 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15453 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15454 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15455 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15456 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15457 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15458 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15459 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15460 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15461 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15462 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15463 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15464 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15465 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15466 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15467 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15468 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15469 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15470 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15471 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15472 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15473 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15474 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15475 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15476 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15477 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15478 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15479 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15480 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15481 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15482 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15483 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15484 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15485 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15486 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15487 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15488 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15489 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15490 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15491 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15492 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15493 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15494 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15495 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15496 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15497 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15498 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15499 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15500 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15501 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15502 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15503 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15504 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15505 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15506 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15507 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15508 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15509 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15510 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15511 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15512 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15513 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15514 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15515 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15516 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15517 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15518 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15519 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15520 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15521 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15522 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15523 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15524 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15525 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15526 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15527 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15528 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15529 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15530 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15531 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15532 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15533 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15534 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15535 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15536 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15537 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15538 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15539 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15540 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15541 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15542 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15543 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15544 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15545 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15546 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15547 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15548 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15549 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15550 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15551 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15552 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15553 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15554 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15555 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15556 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15557 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15558 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15559 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15560 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15561 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15562 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15563 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15564 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15565 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15566 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15567 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15568 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15569 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15570 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15571 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15572 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15573 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15574 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15575 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15576 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15577 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15578 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15579 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15580 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15581 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15582 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15583 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15584 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15585 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15586 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15587 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15588 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15589 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15590 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15591 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15592 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15593 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15594 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15595 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15596 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15597 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15598 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15599 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15600 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15601 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15602 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15603 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15604 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15605 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15606 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15607 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15608 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15609 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15610 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15611 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15612 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15613 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15614 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15615 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15616 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15617 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15618 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15619 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15620 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15621 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15622 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15623 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15624 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15625 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15626 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15627 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15628 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15629 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15630 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15631 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15632 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15633 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15634 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15635 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15636 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15637 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15638 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15639 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15640 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15641 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15642 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15643 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15644 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15645 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15646 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15647 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15648 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15649 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15650 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 15651 ##############################
# ...
# ########################################################################
# ##########################################################################
# ############################# new element 17037 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17038 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17039 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17040 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17041 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17042 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17043 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17044 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17045 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17046 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17047 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17048 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17049 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17050 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17051 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17052 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17053 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17054 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17055 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17056 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17057 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17058 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17059 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17060 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17061 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17062 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17063 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17064 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17065 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17066 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17067 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17068 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17069 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17070 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17071 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17072 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17073 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17074 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17075 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17076 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17077 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17078 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17079 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17080 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17081 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17082 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17083 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17084 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17085 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17086 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17087 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17088 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17089 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17090 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17091 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17092 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17093 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17094 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17095 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17096 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17097 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17098 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17099 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17100 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17101 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17102 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17103 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17104 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17105 ##############################
# ########################################################################
# ##########################################################################
# ############################# new element 17106 ##############################
# ########################################################################
# Der Code hat 12.82 Minuten gedauert.

# %%
# Initializes the three new columns

final_data_3_2000000['subword'] = None
final_data_3_2000000['word_index'] = None
final_data_3_2000000['contextualized_vectors'] = None
# Out:
# <ipython-input-17-48579a03cb93>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_data_3_2000000['subword'] = None
# <ipython-input-17-48579a03cb93>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_data_3_2000000['word_index'] = None
# <ipython-input-17-48579a03cb93>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_data_3_2000000['contextualized_vectors'] = None

# %%
final_data_3_2000000.shape
# Out:
# (1765986, 10)

# %%
final_data_3_2000000
# Out:
#                                               Sentence_row  Word_count  \
# 4104203  It 's the EquuSearch volunteers who   really s...        15.0
# 4104204  It 's the EquuSearch volunteers who   really s...        15.0
# 4104205  It 's the EquuSearch volunteers who   really s...        15.0
# 4104206  It 's the EquuSearch volunteers who   really s...        15.0
# 4104207  It 's the EquuSearch volunteers who   really s...        15.0
# ...                                                    ...         ...
# 5910736  Barak is facing mounting pressure ICH from wit...        44.0
# 5910737  Barak is facing mounting pressure ICH from wit...        44.0
# 5910738  Barak is facing mounting pressure ICH from wit...        44.0
# 5910739  Barak is facing mounting pressure ICH from wit...        44.0
# 5910740  Barak is facing mounting pressure ICH from wit...        44.0
#
#                                                   Sentence  Sentence_no  \
# 4104203  ('It', "'s", 'the', 'EquuSearch', 'volunteers'...       200232
# 4104204  ('It', "'s", 'the', 'EquuSearch', 'volunteers'...       200232
# 4104205  ('It', "'s", 'the', 'EquuSearch', 'volunteers'...       200232
# 4104206  ('It', "'s", 'the', 'EquuSearch', 'volunteers'...       200232
# 4104207  ('It', "'s", 'the', 'EquuSearch', 'volunteers'...       200232
# ...                                                    ...          ...
# 5910736  ('Barak', 'is', 'facing', 'mounting', 'pressur...       307833
# 5910737  ('Barak', 'is', 'facing', 'mounting', 'pressur...       307833
# 5910738  ('Barak', 'is', 'facing', 'mounting', 'pressur...       307833
# 5910739  ('Barak', 'is', 'facing', 'mounting', 'pressur...       307833
# 5910740  ('Barak', 'is', 'facing', 'mounting', 'pressur...       307833
#
#                Word    POS  end_labels subword word_index  \
# 4104203  EquuSearch  PROPN         NaN    None       None
# 4104204  volunteers   NOUN         NaN    None       None
# 4104205         who   PRON         NaN    None       None
# 4104206              SPACE         NaN    None       None
# 4104207      really    ADV         NaN    None       None
# ...             ...    ...         ...     ...        ...
# 5910736        drop   VERB         NaN    None       None
# 5910737         out    ADP         NaN    None       None
# 5910738          of    ADP         NaN    None       None
# 5910739         the    DET         NaN    None       None
# 5910740        race   NOUN         NaN    None       None
#
#         contextualized_vectors
# 4104203                   None
# 4104204                   None
# 4104205                   None
# 4104206                   None
# 4104207                   None
# ...                        ...
# 5910736                   None
# 5910737                   None
# 5910738                   None
# 5910739                   None
# 5910740                   None
#
# [1765986 rows x 10 columns]

# %%
"""
    We iterate through the dataframe using a for loop. For all rows that have the same sentence,
    we define a dictionary called 'word_already_seen', so that words that appear more than once
    in a sentence don't receive the same index,
    but rather a unique index.

"""


def find_index_2(curr_word: str, sub_tokens: list, already_seen: Dict):
    last_index = already_seen.get(curr_word, 0)
    curr_index = sub_tokens.index(curr_word, last_index + 1)
    already_seen[curr_word] = curr_index
    return curr_index

# %%
import traceback

"""This step is the main function for assigning 'subwords', word_index,
and contextualized vectors to each word in the dataframe."""


old_sentence_list = ""
counter = -1
hauptworter_fuer_current_satz = []
teilwoerter_fuer_current_satz = []
embed_index_fuer_current_satz = []
tokens_fuer_current_satz = []
previous_tokens = []
previous_sentence_no = None
word_already_seen = Dict

tensor_output = []
for index, row in final_data_3_2000000.iterrows():
    sentence_list = row["Sentence_row"]


     #Search for the index in 'texts_without_duplicates'. This is important because it corresponds to the
     #index for contextualized vectors, subwords, main_words, and EmbeddingIndex


    index_of_Sentence = texts_ohne_dublikate_3_2000000.index(sentence_list)
    tokens_fuer_current_satz = all_tokens_3_2000000[index_of_Sentence]

    hauptworter_fuer_current_satz =all_main_tokens_3_2000000[index_of_Sentence]
    teilwoerter_fuer_current_satz = all_subtokens_3_2000000[index_of_Sentence]
    embed_index_fuer_current_satz = all_embeded_index_3_2000000[index_of_Sentence]
    sentence_no_fuer_current_satz = row['Sentence_no']
    contextualized_vectors_fuer_current_satz = all_contextualized_vectors_3_2000000[index_of_Sentence]

    #When we come across a new sentence or the same sentence with a different sentence number,
    #the 'word_already_seen' is emptied


    if previous_tokens != tokens_fuer_current_satz or previous_sentence_no != sentence_no_fuer_current_satz:
        #print(f"changing from S_no:{previous_sentence_no} to-> S_no:{sentence_no_fuer_current_satz}")
        word_already_seen = dict()
    current_word = row['Word']
    index_of_word = -1
    if current_word in hauptworter_fuer_current_satz:
        index_of_hauptwort = hauptworter_fuer_current_satz.index(current_word)
        final_data_3_2000000.at[index, 'subword'] = teilwoerter_fuer_current_satz[index_of_hauptwort]
        index_of_word = embed_index_fuer_current_satz[index_of_hauptwort]
        final_data_3_2000000.at[index, "word_index"] = index_of_word

    elif current_word in tokens_fuer_current_satz:
        try:
            index_of_word = find_index_2(current_word, tokens_fuer_current_satz, word_already_seen)
        except Exception as e:
            print(f"""*****************************************************************************
********************************** index {index} *******************************************
*************************************************************************************""")
            #print(index)
            #print("current_word", current_word)
            #print("tokens_fuer_current_satz:")
            #print(tokens_fuer_current_satz)
            #print("word already seen")
            #print(word_already_seen)
            traceback.print_exc()
            break
        final_data_3_2000000.at[index, "word_index"] = index_of_word

    if index_of_word != -1:

        # If 'current_word' appears in main_word or in 'tokens', then the index must be a value that is >= 0

        e = contextualized_vectors_fuer_current_satz[index_of_word].tolist()
        tensor_output.append(e)

    else:
      # For the word (which was previously tokenized in our dataframe using spaCy), the tokenizer couldn't generate a value
        tensor_output.append(None)

    previous_tokens = tokens_fuer_current_satz
    previous_sentence_no = sentence_no_fuer_current_satz

    print("hallo there")

final_data_3_2000000['contextualized_vectors'] = tensor_output

# Filtered by end labels (only 0 and 1 labels are taken)

filtered_endlabels=final_data_3_2000000[(final_data_3_2000000["end_labels"] >= 0.0) & (final_data_3_2000000["end_labels"] <= 1.0)]

#  The NaN values from the "contextualized_vectors" are removed

filtered_endlabels.dropna(subset=["contextualized_vectors"],inplace=True)

# Due to the sentences repeating themselves in the dataset, similar embedding vectors are remove
end_embedding = filtered_endlabels.drop_duplicates(subset="contextualized_vectors")
end_embedding.to_csv("/content/drive/My Drive/embedding_data/embedding_3_2000000.csv")
print("Fertig")
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# hallo there
# <ipython-input-21-8c9568362402>:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_data_3_2000000['contextualized_vectors'] = tensor_output
# <ipython-input-21-8c9568362402>:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_endlabels.dropna(subset=["contextualized_vectors"],inplace=True)
# Fertig

# %%
# Read all three files
df_1=pd.read_csv(f"/content/drive/My Drive/embedding_data/embedding_1_2000000.csv", low_memory=False)
df_2=pd.read_csv(f"/content/drive/My Drive/embedding_data/embedding_2_2000000.csv", low_memory=False)
df_3=pd.read_csv(f"/content/drive/My Drive/embedding_data/embedding_3_2000000.csv", low_memory=False)

# %%
# Concatenates all three files and creates a single final file with complete embedding data.
concat_data = pd.concat([df_1,df_2,df_3],ignore_index=True)

# %%
# Save all data
concat_data_embedding=concat_data.to_csv(f"/content/drive/My Drive/embedding_data/concat_all_embedding_data.csv")
